# %% [markdown]
# # Notebook for making feature selection tables(TableS13-15), metric tables (TableS19-TableS22) and preparing for feature selection table (Table3)

# %%
# Configutation part #

# Directory with matrix after deduplication
data_dir = "../db/cv_bess_files.2"
# Directory with matrix before deduplication
data_dir_pre = "../db/cv_bess_files"

# Output from py_picasso with scad parameter
output_scad = './output_picasso/scad_output'
# Output from py_picasso with mcp parameter
output_mcp = './output_picasso/mcp_output'
# Output from py_picasso with l1 parameter
output_l1 = './output_picasso/l1_output'

# Output path to scad
final_output_scad = './final_output_scad'
# Output path to mcp
final_output_mcp = './final_output_mcp'
# Output path to l1
final_output_l1 = './final_output_l1'

# Annotation file
annotation_file = '../db/AL123456_rev.gff'
# Resistance genes file
resistance_gene_file = '../db/resistance_genes.csv'

# List of gamma parameter for scad regularization
gammas_scad = [3, 5, 10, 15]
# List of gamma parameter for mcp regularization
gammas_mcp = [3, 5, 10, 15]
# L1 hasn't gamma paramter but it was added for simplification programming code
gammas_l1 = [1]

######################

# %%
import os

from locale import atof

from copy import deepcopy

import pandas as pd
import numpy as np

from tqdm import tqdm

from scipy.stats import fisher_exact

# %%
data_dir = "../../datasets/cv_bess_files_031121.2"
data_dir_pre = "../../datasets/cv_bess_files_031121"

output_scad = './output_picasso/scad_output'
output_mcp = './output_picasso/mcp_output'
output_l1 = './output_picasso/l1_output'

final_output_scad = './final_output_scad'
final_output_mcp = './final_output_mcp'
final_output_l1 = './final_output_l1'

if not os.path.exists(final_output_scad):
    os.makedirs(final_output_scad)
    
if not os.path.exists(final_output_mcp):
    os.makedirs(final_output_mcp)
    
if not os.path.exists(final_output_l1):
    os.makedirs(final_output_l1)
    

thr = '3'

drugs = ['Kanamycin', 'Amikacin', 'Streptomycin', 'Ofloxacin',
         'Moxifloxacin', 'Isoniazid', 'Rifampicin', 'Ethambutol',
         'Pyrazinamide', 'Capreomycin', 'Ethionamide', 'Prothionamide',
         'Ciprofloxacin']

annotation = pd.read_csv(annotation_file, sep='\t', index_col=None, header=None)
annotation = annotation[annotation[2] == "CDS"]
annotation['gene'] = [x.split(';')[2].split()[-1] for x in annotation[8]]
annotation['seq'] = [x.split(';')[-1].split()[1][1:] for x in annotation[8]]
annotation = annotation[['gene', 'seq']]

res_data = pd.read_csv(resistance_file, sep='\t', 
                               index_col=None, header=0)

# %%
if not os.path.exists(final_output_scad):
    os.makedirs(final_output_scad)
    
if not os.path.exists(output_mcp):
    os.makedirs(final_output_mcp)
    
if not os.path.exists(output_l1):
    os.makedirs(final_output_l1)

# %% [markdown]
# ## Support Functions

# %%
def represents_int(s):
    try: 
        int(s)
        return True
    except ValueError:
        return False

# %%
def conj_matrix(X):
    value00 = len(X[(X.iloc[:,0] == 0) & (X.iloc[:,1] == 0)])
    value01 = len(X[(X.iloc[:,0] == 0) & (X.iloc[:,1] == 1)])
    value10 = len(X[(X.iloc[:,0] == 1) & (X.iloc[:,1] == 0)])
    value11 = len(X[(X.iloc[:,0] == 1) & (X.iloc[:,1] == 1)])
    return [value00, value01, value10, value11]

def fisher(X):
    n = len(X)
    [value00, value01, value10, value11] = conj_matrix(X)
    return fisher_exact([[value00, value01], [value10, value11]])[1]

# %%
def get_ind_by_name(pos_info, name, drug):
    if name.split('_')[-1] == 'domain':
        gene = "_".join(name.split('_')[:-1])
        temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == 'changed')]
    elif name.split('_')[-1] == 'broken':
        gene = "_".join(name.split('_')[:-1])
        temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == 'broken')]
    elif name.split('_')[-1] == 'snp':
        gene = "_".join(name.split('_')[:-3])
        pos = name.split('_')[-3]
        ind = name.split('_')[-2]
        temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == pos) & (pos_info['ind2'] == ind) & (pos_info['act'] == 'snp')]
    elif name.split('_')[-1] == 'del':
        gene = "_".join(name.split('_')[:-3])
        pos = name.split('_')[-3]
        ind = name.split('_')[-2]
        if represents_int(ind):
            temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == pos) & (pos_info['ind1'] == ind)  & (pos_info['ind2'] == 'del')]
        else:
            temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == pos) & (pos_info['ind2'] == ind)  & (pos_info['act'] == 'del')]
    elif name.split('_')[-1] == 'ins':
        gene = "_".join(name.split('_')[:-3])
        pos = name.split('_')[-3]
        ind = name.split('_')[-2]
        temp = pos_info[(pos_info['gene'] == gene) & (pos_info['pos'] == pos) & (pos_info['ind2'] == ind)  & (pos_info['act'] == 'ins')]

    if len(temp) == 0: 
        return -1
    else: 
        return temp.index[0]
    
def get_name_by_ind(pos_info, j, drug):
    temp = pos_info.iloc[j]
    gene, pos, ind1, ind2, act = temp['gene'], temp['pos'], temp['ind1'], temp['ind2'], temp['act']

    if pos == 'changed':
        return f"{gene}_domain"
    elif pos == 'broken':
        return f"{gene}_broken"
    elif act == 'snp':
        return f"{gene}_{pos}_{ind2}_snp"
    elif ind2 == 'del':
        return f"{gene}_{pos}_{ind1}_{ind2}"
    elif act == 'del':
        return f"{gene}_{pos}_{ind2}_{act}"
    elif act == 'ins':
        return f"{gene}_{pos}_{ind2}_{act}"
    
def get_description(pos_info, ind):
    gene, pos, fr, to, act = pos_info.loc[ind].values
    if act == 'snp':
        return [gene, pos, 'SNV', fr, to]
    elif act == 'ins':
        return [gene, pos, 'Insertion', fr, to]
    elif act == 'del':
        return [gene, pos, 'Deletion', fr, to]
    elif to == 'del':
        seq = annotation[annotation['gene'] == gene]['seq'].to_numpy()[0]
        fr = seq[int(pos)-1: int(pos)+int(fr)]
        return [gene, pos, 'Deletion', fr, "-"]
    elif pos == 'changed':
        temp = [i for i in gene.split('_') if not represents_int(i)]
        new_gene = "_".join(temp[:-1])
        domain = "_".join(gene.split('_')[len(new_gene.split('_')):])
        return [new_gene, '-', f'{domain} is changed', '-', '-']
        return f"In {new_gene} PFAM {domain} is changed"
    elif pos == 'broken':
        return [gene, '-', 'Broken', '-', '-']

# %% [markdown]
# ## Add statical info

# %% [markdown]
# ### SCAD

# %%
# Считаем метрики
result= pd.DataFrame(index=drugs, columns=['auc',  'sensitivity',
                                           'specivity', 'npv', 
                                           'ppv'])

for drug in tqdm(drugs):
    pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.0", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
    pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
    
    auc_data = pd.DataFrame()
    for gamma in gammas_scad:
        temp = pd.read_csv(f"{output_scad}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info_temp = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info_temp.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        
        temp = pd.read_csv(f"{output_scad}/{drug}/{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                       sep='\t', index_col=0, header=0)
        temp['name'] = [", ".join([get_name_by_ind(pos_info_temp, int(i), drug) for i in str(x).split(', ')])
                        for x in temp.index]
        
        
        indeces = [int(str(x).split(', ')[0]) for x in temp.index]
        indeces = [get_ind_by_name(pos_info, get_name_by_ind(pos_info_temp, i, drug), drug) for i in indeces]
        
        sel_indeces = deepcopy(indeces)
        while -1 in sel_indeces: sel_indeces.remove(-1)
        
        X_test = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.test.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X_train = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.train.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X = pd.concat([X_train, X_test])
        
        y_train= pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.train.0", sep=' ', 
                             index_col=None, header=None)
        y_test = pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.test.0", sep=' ', 
                             index_col=None, header=None)
        y = pd.concat([y_train, y_test])
        X['y'] = y.to_numpy().ravel()


        pvalues = []
        values00 = []
        values01 = []
        values10 = []
        values11 = []

        for j in indeces:
            if j == -1: 
                pvalues.append('-')
                [value00, value01, value10, value11] = ['-', '-', '-', '-']
            else: 
                pvalues.append(fisher(X[[j, 'y']]))
                [value00, value01, value10, value11] = conj_matrix(X[[j, 'y']])
            values00.append(value00)
            values01.append(value01)
            values10.append(value10)
            values11.append(value11)
        temp['0_0'] = values00
        temp['0_1'] = values01
        temp['1_0'] = values10
        temp['1_1'] = values11
                
        
        temp['pvalue'] = pvalues

        temp.to_csv(f"{output_scad}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                    sep='\t', header=True, index=True)
# Out:
# 100%|██████████| 13/13 [07:12<00:00, 33.30s/it]

# %% [markdown]
# ### MCP

# %%
# Считаем метрики
result= pd.DataFrame(index=drugs, columns=['auc',  'sensitivity',
                                           'specivity', 'npv', 
                                           'ppv'])

for drug in tqdm(drugs):
    pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.0", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
    pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
    
    auc_data = pd.DataFrame()
    for gamma in gammas_scad:
        temp = pd.read_csv(f"{output_mcp}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info_temp = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info_temp.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        
        temp = pd.read_csv(f"{output_mcp}/{drug}/{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                       sep='\t', index_col=0, header=0)
        temp['name'] = [", ".join([get_name_by_ind(pos_info_temp, int(i), drug) for i in str(x).split(', ')])
                        for x in temp.index]
        
        
        indeces = [int(str(x).split(', ')[0]) for x in temp.index]
        indeces = [get_ind_by_name(pos_info, get_name_by_ind(pos_info_temp, i, drug), drug) for i in indeces]
        
        sel_indeces = deepcopy(indeces)
        while -1 in sel_indeces: sel_indeces.remove(-1)
            
        X_test = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.test.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X_train = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.train.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X = pd.concat([X_train, X_test])
        
        y_train= pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.train.0", sep=' ', 
                             index_col=None, header=None)
        y_test = pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.test.0", sep=' ', 
                             index_col=None, header=None)
        y = pd.concat([y_train, y_test])
        X['y'] = y.to_numpy().ravel()


        pvalues = []
        values00 = []
        values01 = []
        values10 = []
        values11 = []

        for j in indeces:
            if j == -1: 
                pvalues.append('-')
                [value00, value01, value10, value11] = ['-', '-', '-', '-']
            else: 
                pvalues.append(fisher(X[[j, 'y']]))
                [value00, value01, value10, value11] = conj_matrix(X[[j, 'y']])
            values00.append(value00)
            values01.append(value01)
            values10.append(value10)
            values11.append(value11)
        temp['0_0'] = values00
        temp['0_1'] = values01
        temp['1_0'] = values10
        temp['1_1'] = values11
                
        
        temp['pvalue'] = pvalues

        temp.to_csv(f"{output_mcp}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                    sep='\t', header=True, index=True)
# Out:
# 100%|██████████| 13/13 [06:36<00:00, 30.52s/it]

# %% [markdown]
# ### l1

# %%
# Считаем метрики
result= pd.DataFrame(index=drugs, columns=['auc',  'sensitivity',
                                           'specivity', 'npv', 
                                           'ppv'])
for drug in tqdm(drugs):
    pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.0", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
    pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
    
    auc_data = pd.DataFrame()
    for gamma in gammas_l1:
        temp = pd.read_csv(f"{output_l1}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info_temp = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                              index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info_temp.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        
        temp = pd.read_csv(f"{output_l1}/{drug}/{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                       sep='\t', index_col=0, header=0)
        temp['name'] = [", ".join([get_name_by_ind(pos_info_temp, int(i), drug) for i in str(x).split(', ')])
                        for x in temp.index]
        
        
        indeces = [int(str(x).split(', ')[0]) for x in temp.index]
        indeces = [get_ind_by_name(pos_info, get_name_by_ind(pos_info_temp, i, drug), drug) for i in indeces]
        
        sel_indeces = deepcopy(indeces)
        while -1 in sel_indeces: sel_indeces.remove(-1)
            
        X_test = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.test.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X_train = pd.read_csv(f"{data_dir_pre}/{drug}.gt.domains.3.train.0", sep=' ', 
                             index_col=None, header=None, usecols=sel_indeces)
        X = pd.concat([X_train, X_test])
        
        y_train= pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.train.0", sep=' ', 
                             index_col=None, header=None)
        y_test = pd.read_csv(f"{data_dir_pre}/{drug}.phen.domains.3.test.0", sep=' ', 
                             index_col=None, header=None)
        y = pd.concat([y_train, y_test])
        X['y'] = y.to_numpy().ravel()


        pvalues = []
        values00 = []
        values01 = []
        values10 = []
        values11 = []

        for j in indeces:
            if j == -1: 
                pvalues.append('-')
                [value00, value01, value10, value11] = ['-', '-', '-', '-']
            else: 
                pvalues.append(fisher(X[[j, 'y']]))
                [value00, value01, value10, value11] = conj_matrix(X[[j, 'y']])
            values00.append(value00)
            values01.append(value01)
            values10.append(value10)
            values11.append(value11)
        temp['0_0'] = values00
        temp['0_1'] = values01
        temp['1_0'] = values10
        temp['1_1'] = values11
                
        
        temp['pvalue'] = pvalues

        temp.to_csv(f"{output_l1}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                    sep='\t', header=True, index=True)
# Out:
#  85%|████████▍ | 11/13 [06:32<01:00, 30.02s/it]

# %% [markdown]
# ## Form final feature selection table

# %% [markdown]
# ## SCAD (TableS13)

# %%
for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_scad:
        temp = pd.read_csv(f"{output_scad}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)
    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    count_features = pd.DataFrame()
    result = pd.DataFrame(columns=['gene', 'pos', 'act', 'from', 'to', 'num', 
                                   'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
    for i in range(5):
        temp = pd.read_csv(f"{output_scad}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        # indeces = [features_info[i][0] for i in indeces]

        count_features = pd.concat([count_features, temp], axis=0)
    count_features['count'] = 1    

    count_features = count_features.groupby(['name']).agg({'coef': np.mean, 
                                                                  'count': np.sum,
                                                                  'pvalue': lambda x: x.iloc[0],
                                                                  '0_0': lambda x: x.iloc[0],
                                                                  '0_1': lambda x: x.iloc[0],
                                                                  '1_0': lambda x: x.iloc[0],
                                                                  '1_1': lambda x: x.iloc[0]})
    
    
    count_features.sort_values('count', ascending=False, inplace=True)
    
    for j in range(len(count_features)):
        names = count_features.index[j]
        coef, count, pvalue, value00, value01, value10, value11 = count_features.to_numpy()[j]
        for name in names.split(', '):
            for i in range(5):
                pos_info = pd.read_csv(f"{data_dir}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
                pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
                pos_info.fillna('Nope', inplace=True)
                ind = get_ind_by_name(pos_info, name, drug)
                if ind != -1:
                    break
                    
            add = pd.DataFrame([[*get_description(pos_info, ind), j, name, coef, pvalue, value00,
                                 value01, value10, value11, count]], 
                              columns=['gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
            result = pd.concat([result, add])
    result.drop(['name'], axis=1, inplace=True)
    result['drug'] = drug
    result.to_csv(f"{final_output_scad}/{drug}.csv", sep='\t', index=False, header=True)

# %%
all_data = pd.DataFrame(columns=['drug', 'gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
for drug in drugs:
    result = pd.read_csv(f"{final_output_scad}/{drug}.csv", sep='\t', index_col=None, header=0)
    result['drug'] = drug
    all_data = pd.concat([all_data, result], axis=0)
all_data.to_csv(f"{final_output_scad}/TableS13.csv", sep='\t', header=True, index=None)

# %% [markdown]
# ### MCP (TableS14)

# %%
for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_mcp:
        temp = pd.read_csv(f"{output_mcp}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)
    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    count_features = pd.DataFrame()
    result = pd.DataFrame(columns=['gene', 'pos', 'act', 'from', 'to', 'num', 
                                   'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
    for i in range(5):
        temp = pd.read_csv(f"{output_mcp}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        # indeces = [features_info[i][0] for i in indeces]

        count_features = pd.concat([count_features, temp], axis=0)
    count_features['count'] = 1    

    count_features = count_features.groupby(['name']).agg({'coef': np.mean, 
                                                                  'count': np.sum,
                                                                  'pvalue': lambda x: x.iloc[0],
                                                                  '0_0': lambda x: x.iloc[0],
                                                                  '0_1': lambda x: x.iloc[0],
                                                                  '1_0': lambda x: x.iloc[0],
                                                                  '1_1': lambda x: x.iloc[0]})
    
    
    count_features.sort_values('count', ascending=False, inplace=True)
    
    for j in range(len(count_features)):
        names = count_features.index[j]
        coef, count, pvalue, value00, value01, value10, value11 = count_features.to_numpy()[j]
        for name in names.split(', '):
            for i in range(5):
                pos_info = pd.read_csv(f"{data_dir}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
                pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
                pos_info.fillna('Nope', inplace=True)
                ind = get_ind_by_name(pos_info, name, drug)
                if ind != -1:
                    break
                    
            add = pd.DataFrame([[*get_description(pos_info, ind), j, name, coef, pvalue, value00,
                                 value01, value10, value11, count]], 
                              columns=['gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
            result = pd.concat([result, add])
    result.drop(['name'], axis=1, inplace=True)
    result['drug'] = drug
    result.to_csv(f"{final_output_mcp}/{drug}.csv", sep='\t', index=False, header=True)

# %%
all_data = pd.DataFrame(columns=['drug', 'gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
for drug in drugs:
    result = pd.read_csv(f"{final_output_mcp}/{drug}.csv", sep='\t', index_col=None, header=0)
    result['drug'] = drug
    all_data = pd.concat([all_data, result], axis=0)
all_data.to_csv(f"{final_output_mcp}/TableS14.csv", sep='\t', header=True, index=None)

# %% [markdown]
# ### l1 (TableS15)

# %%
for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_l1:
        temp = pd.read_csv(f"{output_l1}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)
    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    count_features = pd.DataFrame()
    result = pd.DataFrame(columns=['gene', 'pos', 'act', 'from', 'to', 'num', 
                                   'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
    for i in range(5):
        temp = pd.read_csv(f"{output_l1}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        # indeces = [features_info[i][0] for i in indeces]

        count_features = pd.concat([count_features, temp], axis=0)
    count_features['count'] = 1    

    count_features = count_features.groupby(['name']).agg({'coef': np.mean, 
                                                                  'count': np.sum,
                                                                  'pvalue': lambda x: x.iloc[0],
                                                                  '0_0': lambda x: x.iloc[0],
                                                                  '0_1': lambda x: x.iloc[0],
                                                                  '1_0': lambda x: x.iloc[0],
                                                                  '1_1': lambda x: x.iloc[0]})
    
    
    count_features.sort_values('count', ascending=False, inplace=True)
    
    for j in range(len(count_features)):
        names = count_features.index[j]
        coef, count, pvalue, value00, value01, value10, value11 = count_features.to_numpy()[j]
        for name in names.split(', '):
            for i in range(5):
                pos_info = pd.read_csv(f"{data_dir}/{drug}.gt.pos.domains.3.{i}", sep='\t', 
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
                pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
                pos_info.fillna('Nope', inplace=True)
                ind = get_ind_by_name(pos_info, name, drug)
                if ind != -1:
                    break
                    
            add = pd.DataFrame([[*get_description(pos_info, ind), j, name, coef, pvalue, value00,
                                 value01, value10, value11, count]], 
                              columns=['gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'name', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
            result = pd.concat([result, add])
    result.drop(['name'], axis=1, inplace=True)
    result['drug'] = drug
    result.to_csv(f"{final_output_l1}/{drug}.csv", sep='\t', index=False, header=True)

# %%
all_data = pd.DataFrame(columns=['drug', 'gene', 'pos', 'act', 'from', 'to', 
                                       'num', 'coef', 'pvalue', '0_0', 
                                       '0_1', '1_0', '1_1', 'count'])
for drug in drugs:
    result = pd.read_csv(f"{final_output_l1}/{drug}.csv", sep='\t', index_col=None, header=0)
    result['drug'] = drug
    all_data = pd.concat([all_data, result], axis=0)
all_data.to_csv(f"{final_output_l1}/TableS15.csv", sep='\t', header=True, index=None)

# %% [markdown]
# ## Define feature selection metrics

# %% [markdown]
# ### SCAD

# %%
scad_result = pd.DataFrame(index=drugs, 
                            columns=['res_gen', 'jacard', 
                                     'sel_true_gene', 'sel_false_gene'])
for drug in drugs:
    auc_data = pd.DataFrame()
    features = pd.DataFrame()
    
    auc_data = pd.DataFrame()
    for gamma in gammas_scad:
        temp = pd.read_csv(f"{output_scad}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t',
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        pos_info.fillna('Nope', inplace=True)
        
        
        temp = pd.read_csv(f"{output_scad}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        description = [", ".join([get_name_by_ind(pos_info, int(i), drug) 
                                 for i in str(x).split(", ")]) for x in temp.index]
        
        temp['Event description'] = description
        temp.drop('name', axis=1)
        
        features = pd.concat([features, temp], axis=0)

    features['count'] = 1

    features = features.groupby(['Event description']).agg({'coef': np.mean, 
                                               'count': np.sum, 
                                               'pvalue': lambda x: x.iloc[0]})
    features.sort_values('count', ascending=False, inplace=True)

    features = features[features['count'] >= 3]

    sel_genes = list(set([x.split('_')[0] for x in features.index]))
    sel_genes = pd.DataFrame(sel_genes, columns=['gene'])
    sel_genes['true'] = sel_genes['gene'].isin(res_data[res_data['drug'] == drug]['gene'])
    sel_genes['temp'] = sel_genes['gene'].isin(res_data[res_data['drug'] != drug]['gene'])
    sel_genes['false'] = ~sel_genes['true'] & sel_genes['temp']

    res_gene = len(res_data[res_data['drug'] == drug])
    sel_true_gene = np.sum(sel_genes['true'])
    sel_false_gene = np.sum(sel_genes['false'])
    jacard = sel_true_gene/(res_gene + len(features) - sel_true_gene)

    scad_result.loc[drug] = [res_gene, jacard, sel_true_gene, sel_false_gene]

scad_result.to_csv(f'{final_output_scad}/scad_feature_metrics.csv', sep='\t',
                  index=True, header=True)

# %% [markdown]
# ### MCP

# %%
mcp_result = pd.DataFrame(index=drugs, 
                            columns=['res_gen', 'jacard', 
                                     'sel_true_gene', 'sel_false_gene'])
for drug in drugs:
    auc_data = pd.DataFrame()
    features = pd.DataFrame()
    
    auc_data = pd.DataFrame()
    for gamma in gammas_mcp:
        temp = pd.read_csv(f"{output_mcp}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t',
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        pos_info.fillna('Nope', inplace=True)
        
        
        temp = pd.read_csv(f"{output_mcp}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        description = [", ".join([get_name_by_ind(pos_info, int(i), drug) 
                                 for i in str(x).split(", ")]) for x in temp.index]
        
        temp['Event description'] = description
        temp.drop('name', axis=1)
        
        features = pd.concat([features, temp], axis=0)

    features['count'] = 1

    features = features.groupby(['Event description']).agg({'coef': np.mean, 
                                               'count': np.sum, 
                                               'pvalue': lambda x: x.iloc[0]})
    features.sort_values('count', ascending=False, inplace=True)

    features = features[features['count'] >= 3]

    sel_genes = list(set([x.split('_')[0] for x in features.index]))
    sel_genes = pd.DataFrame(sel_genes, columns=['gene'])
    sel_genes['true'] = sel_genes['gene'].isin(res_data[res_data['drug'] == drug]['gene'])
    sel_genes['temp'] = sel_genes['gene'].isin(res_data[res_data['drug'] != drug]['gene'])
    sel_genes['false'] = ~sel_genes['true'] & sel_genes['temp']

    res_gene = len(res_data[res_data['drug'] == drug])
    sel_true_gene = np.sum(sel_genes['true'])
    sel_false_gene = np.sum(sel_genes['false'])
    jacard = sel_true_gene/(res_gene + len(features) - sel_true_gene)

    mcp_result.loc[drug] = [res_gene, jacard, sel_true_gene, sel_false_gene]

mcp_result.to_csv(f'{final_output_mcp}/mcp_feature_metrics.csv', sep='\t',
                  index=True, header=True)

# %% [markdown]
# ### l1

# %%
l1_result = pd.DataFrame(index=drugs, 
                            columns=['res_gen', 'jacard', 
                                     'sel_true_gene', 'sel_false_gene'])
for drug in drugs:
    auc_data = pd.DataFrame()
    features = pd.DataFrame()
    
    auc_data = pd.DataFrame()
    for gamma in gammas_l1:
        temp = pd.read_csv(f"{output_l1}/{drug}/auc_{gamma}.csv", sep='\t')
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data.reset_index(inplace=True)
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['mean_auc'])][['l', 'gamma']].values

    for i in range(5):
        pos_info = pd.read_csv(f"{data_dir_pre}/{drug}.gt.pos.domains.3.{i}", sep='\t',
                                  index_col=None, header=None, usecols=[0, 1, 2, 3, 4])
        pos_info.columns = ['gene', 'pos', 'ind1', 'ind2', 'act']
        pos_info.fillna('Nope', inplace=True)
        
        
        temp = pd.read_csv(f"{output_l1}/{drug}/fisher_{l_max:.5f}_{gamma_max:.1f}_{i}.csv", 
                           sep='\t', index_col=0, header=0)
        
        description = [", ".join([get_name_by_ind(pos_info, int(i), drug) 
                                 for i in str(x).split(", ")]) for x in temp.index]
        
        temp['Event description'] = description
        temp.drop('name', axis=1)
        
        features = pd.concat([features, temp], axis=0)

    features['count'] = 1

    features = features.groupby(['Event description']).agg({'coef': np.mean, 
                                               'count': np.sum, 
                                               'pvalue': lambda x: x.iloc[0]})
    features.sort_values('count', ascending=False, inplace=True)

    features = features[features['count'] >= 3]

    sel_genes = list(set([x.split('_')[0] for x in features.index]))
    sel_genes = pd.DataFrame(sel_genes, columns=['gene'])
    sel_genes['true'] = sel_genes['gene'].isin(res_data[res_data['drug'] == drug]['gene'])
    sel_genes['temp'] = sel_genes['gene'].isin(res_data[res_data['drug'] != drug]['gene'])
    sel_genes['false'] = ~sel_genes['true'] & sel_genes['temp']

    res_gene = len(res_data[res_data['drug'] == drug])
    sel_true_gene = np.sum(sel_genes['true'])
    sel_false_gene = np.sum(sel_genes['false'])
    jacard = sel_true_gene/(res_gene + len(features) - sel_true_gene)

    l1_result.loc[drug] = [res_gene, jacard, sel_true_gene, sel_false_gene]

l1_result.to_csv(f'{final_output_l1}/l1_feature_metrics.csv', sep='\t',
                  index=True, header=True)

# %% [markdown]
# ## Create metrics table

# %% [markdown]
# ### SCAD (TableS19)

# %%
metrics_scad = pd.DataFrame(index=drugs, columns=['auc', 'sensitivity', 'specificity', 'npv', 'ppv'])

for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_scad:
        temp = pd.read_csv(f"{output_scad}/{drug}/auc_{gamma}.csv", sep='\t', header=0, index_col=None)
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data  = auc_data[['l', 'mean_auc', 'mean_sensitivity', 
                          'mean_specificity', 'mean_npv', 'mean_ppv', 'gamma']]
    auc_data.columns = ['l', 'auc', 'sensitivity', 'specificity', 'npv', 'ppv', 'gamma']
    auc_data.reset_index(inplace=True)
    
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['auc'])][['l', 'gamma']].values
    temp = auc_data[(auc_data['l'] == l_max) & (auc_data['gamma'] == gamma_max)]
    
    metrics_scad.loc[drug] = temp[['auc', 'sensitivity', 
                                   'specificity', 'npv', 'ppv']].values
metrics_scad.to_csv(f'{final_output_scad}/TableS19.csv', sep='\t', index=True, header=True)

# %% [markdown]
# ### MCP (TableS20)

# %%
metrics_mcp = pd.DataFrame(index=drugs, columns=['auc', 'sensitivity', 'specificity', 'npv', 'ppv'])

for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_mcp:
        temp = pd.read_csv(f"{output_mcp}/{drug}/auc_{gamma}.csv", sep='\t', header=0, index_col=None)
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data  = auc_data[['l', 'mean_auc', 'mean_sensitivity', 
                          'mean_specificity', 'mean_npv', 'mean_ppv', 'gamma']]
    auc_data.columns = ['l', 'auc', 'sensitivity', 'specificity', 'npv', 'ppv', 'gamma']
    auc_data.reset_index(inplace=True)
    
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['auc'])][['l', 'gamma']].values
    temp = auc_data[(auc_data['l'] == l_max) & (auc_data['gamma'] == gamma_max)]
    
    metrics_mcp.loc[drug] = temp[['auc', 'sensitivity', 
                                   'specificity', 'npv', 'ppv']].values
metrics_mcp.to_csv(f'{final_output_mcp}/TableS20.csv', sep='\t', index=True, header=True)

# %% [markdown]
# ### l1 (TableS21)

# %%
metrics_l1 = pd.DataFrame(index=drugs, columns=['auc', 'sensitivity', 'specificity', 'npv', 'ppv'])

for drug in drugs:
    auc_data = pd.DataFrame()
    for gamma in gammas_l1:
        temp = pd.read_csv(f"{output_l1}/{drug}/auc_{gamma}.csv", sep='\t', header=0, index_col=None)
        temp['gamma'] = gamma
        auc_data = pd.concat([auc_data, temp], axis=0)

    auc_data  = auc_data[['l', 'mean_auc', 'mean_sensitivity', 
                          'mean_specificity', 'mean_npv', 'mean_ppv', 'gamma']]
    auc_data.columns = ['l', 'auc', 'sensitivity', 'specificity', 'npv', 'ppv', 'gamma']
    auc_data.reset_index(inplace=True)
    
    l_max, gamma_max = auc_data.loc[np.argmax(auc_data['auc'])][['l', 'gamma']].values
    temp = auc_data[(auc_data['l'] == l_max) & (auc_data['gamma'] == gamma_max)]
    
    metrics_l1.loc[drug] = temp[['auc', 'sensitivity', 
                                   'specificity', 'npv', 'ppv']].values
metrics_l1.to_csv(f'{final_output_l1}/TableS21.csv', sep='\t', index=True, header=True)
